# %%
    import pandas as pd
my_file= pd.read_csv("C:\\Users\\venkata sai\\Downloads\\company_sales_data.csv")
print(my_file)
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %%
import matplotlib.pyplot as plt
months=[i for i in my_file.month_number ]
tot_profit=[j for j in my_file.total_profit]
products=my_file.columns
product=products[1:len(products)-2]
colors=["c","m","r","k","c","m"]

plt.plot(months,tot_profit,color="k",label="profit line")
plt.xlabel("month")
plt.ylabel("profit")
plt.show()
#for i in product:
 #   i=[j for j in my_file.i]
  #  print(shampoo)
facecream=[i for i in my_file.facecream]
facewash=[i for i in my_file.facewash]
toothpaste=[i for i in my_file.toothpaste]       #my_file.value
bathingsoap=[i for i in my_file.bathingsoap]
shampoo=[i for i in my_file.shampoo]
moisturizer=[i for i in my_file.moisturizer]


plt.plot(months,facecream,label="facecream",color="k")
plt.plot(months,facewash,label="facewash",color="c")
plt.plot(months,toothpaste,label="toothpaste",color="m")
plt.plot(months,bathingsoap,label="bathingsoap",color="r")
plt.plot(months,shampoo,label="shampoo")
plt.plot(months,moisturizer,label="moisturizer")
plt.legend()
plt.show()
#facecream,facewash,thoothpaste,bathingsoap,shampoo,moisturizer
k=my_file.sum(axis=0)
m=k[1:len(k)-2]
n=m.values
plt.pie(n,labels=product,startangle=180,shadow=True,autopct="%1.1f%%",colors=["c","m","r","k","b","g"])
plt.show()

# %% [markdown]
# ##
